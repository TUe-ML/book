# %% [markdown]
# # Nonconvex matrix factorization

# %% [markdown]
# The following two plots show the error of the $f(x,y) = (1-xy)^2$ in two different views.
#
# In blue, we can see the optimal minimizers where $y=\frac{1}{x}$.
#
# The line in red shows that this is not a convex function, as it connects two points, global minimizers, going below the function $f$.

# %%
import plotly.graph_objects as go
import numpy as np
import pandas as pd
lim = 1.35


# Generate data
x = np.linspace(-lim, lim, 100)
y = np.linspace(-lim, lim, 100)
xGrid, yGrid = np.meshgrid(y, x)
error = (1 - xGrid * yGrid)**2
error[error>2] = np.nan

fig = go.Figure(
    data=[go.Surface(
        x=x, y=y, z=error,
        colorscale='Blackbody_r', showscale=True,
        contours = {
            "z": {"show": True, "start": 0, "end": 100, "size": .1}
        },
    ),]
    
)


# Create the line of minimal error: y = 1/x, z = 0
x_line = np.linspace(0.001, lim, 200)
# Avoid dividing by zero
x_line = x_line[np.abs(x_line) > 0.75]
y_line = 1 / x_line
z_line = np.zeros_like(x_line)

fig.add_trace(
    go.Scatter3d(
        x=x_line,
        y=y_line,
        z=z_line,
        mode='lines',
        line=dict(color='blue', width=6),
        name='Min Error Line (y = 1/x)'
    )
)


# Create the line of minimal error: y = 1/x, z = 0
x_line = np.linspace(-0.001, -lim, 200)
# Avoid dividing by zero
x_line = x_line[np.abs(x_line) > 0.75]
y_line = 1 / x_line
z_line = np.zeros_like(x_line)

fig.add_trace(
    go.Scatter3d(
        x=x_line,
        y=y_line,
        z=z_line,
        mode='lines',
        line=dict(color='blue', width=6),
        showlegend=False  #
    )
)

x_line = np.linspace(1, -1, 200)
y_line = np.linspace(1, -1, 200)
z_line = np.zeros_like(x_line)
fig.add_trace(
    go.Scatter3d(
        x=x_line,
        y=y_line,
        z=z_line,
        mode='lines',
        line=dict(color='red', width=6),
        showlegend=False  #
    )
)

fig.update_layout(
    title=dict(text='$(1-xy)^2$'),
    autosize=False,
    width=500, height=500,
    margin=dict(l=65, r=50, b=65, t=90),
    scene=dict(
        zaxis = dict(range=[0, 2]) # Limit z-axis from 10 to 50
    ),
 )
fig.show(renderer="sphinx_gallery")
# fig
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="89df1d13-eeaa-4612-adbe-6180bec49269" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("89df1d13-eeaa-4612-adbe-6180bec49269")) {                    Plotly.newPlot(                        "89df1d13-eeaa-4612-adbe-6180bec49269",                        [{"colorscale":[[0.0,"rgb(160,200,255)"],[0.25,"rgb(255,255,255)"],[0.5,"rgb(230,210,0)"],[0.75,"rgb(230,0,0)"],[1.0,"rgb(0,0,0)"]],"contours":{"z":{"end":100,"show":true,"size":0.1,"start":0}},"showscale":true,"x":{"dtype":"f8","bdata":"mpmZmZmZ9b8qQZ4S5Cn1v7vooosuuvS\u002fS5CnBHlK9L\u002fbN6x9w9rzv2vfsPYNa\u002fO\u002f\u002fIa1b1j78r+MLrrooovyvxzWvmHtG\u002fK\u002frH3D2jes8b89JchTgjzxv83MzMzMzPC\u002fXnTRRRdd8L\u002fcN6x9w9rvv\u002fyGtW9Y++6\u002fHNa+Ye0b7r89JchTgjztv1500UUXXey\u002ffsPaN6x967+fEuQpQZ7qv
002fVII8JchT0r+UIE8J8pTQv7B9w9o3rM2\u002fMLrooosuyr+w9g1r37DGvzAzMzMzM8O\u002fcN+w9g1rv79wWPuGtW+4v3DRRRdddLG\u002fAJUgTwnypL8AHNa+Ye2LvwAc1r5h7Ys\u002fAJUgTwnypD9w0UUXXXSxP3BY+4a1b7g\u002fcN+w9g1rvz84MzMzMzPDP7D2DWvfsMY\u002fMLrooosuyj+wfcPaN6zNP5QgTwnylNA\u002fVII8JchT0j8U5ClBnhLUP9RFF1100dU\u002fkKcEeUqQ1z9QCfKUIE\u002fZPxBr37D2Dds\u002fzMzMzMzM3D+MLrrooovePybIU4I8JeA\u002fBnlKkKcE4T\u002fkKUGeEuThP8TaN6x9w+I\u002fpIsuuuii4z+CPCXIU4LkP2TtG9a+YeU\u002fQJ4S5ClB5j8gTwnylCDnPwAAAAAAAOg\u002f4LD2DWvf6D\u002fAYe0b1r7pP6AS5ClBnuo\u002fgMPaN6x96z9cdNFFF13sPzwlyFOCPO0\u002fHNa+Ye0b7j\u002f8hrVvWPvuP9w3rH3D2u8\u002fXnTRRRdd8D\u002fOzMzMzMzwPzwlyFOCPPE\u002frH3D2jes8T8c1r5h7RvyP4wuuuiii\u002fI\u002f\u002fIa1b1j78j9s37D2DWvzP9w3rH3D2vM\u002fSpCnBHlK9D+66KKLLrr0PypBnhLkKfU\u002fmpmZmZmZ9T8="},"z":{"dtype":"f8","bdata":"a0Rpb\u002fCl5T9J0ztf48DjP8CRZgQM8uE\u002fyH\u002fpXmo54D\u002fKOond\u002fC3dPynV72eQFdo\u002fvM4GXY8p1z9zJ868+WnUP1TfRYfP1tE\u002fvuzbeCHgzj8u2Yy4emvKP+qDns2qT8Y\u002fAO0QuLGMwj\u002fFKMjvHkW+Pyf0LxqIIrg\u002fOzxZ756xsj\u002f7AYjexuSrP7yE4DOryaM\u002flwF4vdUjmj+j2Gl8F\u002faOP6Am36fhY34\u002fBs0EBt7sYz8fFa5H4XokP\u002fMpguzNYEM\u002fZ8j1OW6ebj\u002fcpj6Ul6aDP17gBXiAmZI\u002f8F\u002fy0Gsmnj8JaXLqBj2mP3Sb7kEzyq4\u002fj+N2d11dtD8P9rf4Tge6P5hCXRJ3McA\u002ffE ...

# %%
lim = 1.35
x = np.linspace(0, 2*lim, 100)
y = np.linspace(0, 2*lim, 100)
xGrid, yGrid = np.meshgrid(y, x)
error = (1 - xGrid * yGrid)**2
error[error>2] = np.nan
fig = go.Figure(
    data=[go.Surface(
        x=x, y=y, z=error,
        colorscale='YlOrRd',
        showscale=True,
        contours = {
            "z": {"show": True, "start": 0.0000000001, "end": 100, "size": .1}
        },
    ),]
    
)
# Create the line of minimal error: y = 1/x, z = 0
x_line = np.linspace(0.001, 2*lim, 200)
# Avoid dividing by zero
x_line = x_line[np.abs(x_line) > 0.38]
y_line = 1 / x_line
z_line = np.zeros_like(x_line)

fig.add_trace(
    go.Scatter3d(
        x=x_line,
        y=y_line,
        z=z_line,
        mode='lines',
        line=dict(color='blue', width=6),
        name='Min Error Line (y = 1/x)'
    )
)

x_line = np.linspace(0.38, 2.5, 200)
y_line = np.linspace(1/0.38, 1/2.5, 200)
z_line = np.zeros_like(x_line)
fig.add_trace(
    go.Scatter3d(
        x=x_line,
        y=y_line,
        z=z_line,
        mode='lines',
        line=dict(color='red', width=6),
        name='Min Error Line (y = 1/x)',
        showlegend=False  #
    )
)


fig.update_layout(
    title=dict(text='$(1-xy)^2$'),
    autosize=False,
    width=500, height=500,
    margin=dict(l=65, r=50, b=65, t=90),
    scene=dict(
        zaxis = dict(range=[0, 2]) # Limit z-axis from 10 to 50
    ),
 )


fig.show(renderer="sphinx_gallery")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="cdb84176-cc38-4319-865a-36d3bc0d0a13" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("cdb84176-cc38-4319-865a-36d3bc0d0a13")) {                    Plotly.newPlot(                        "cdb84176-cc38-4319-865a-36d3bc0d0a13",                        [{"colorscale":[[0.0,"rgb(255,255,204)"],[0.125,"rgb(255,237,160)"],[0.25,"rgb(254,217,118)"],[0.375,"rgb(254,178,76)"],[0.5,"rgb(253,141,60)"],[0.625,"rgb(252,78,42)"],[0.75,"rgb(227,26,28)"],[0.875,"rgb(189,0,38)"],[1.0,"rgb(128,0,38)"]],"contours":{"z":{"end":100,"show":true,"size":0.1,"start":1e-10}},"showscale":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAADuG9a+Ye2bP+4b1r5h7as\u002f8pQgTwnytD\u002fuG9a+Ye27P3XRRRdddME\u002f8pQgTwnyxD9wWPuGtW\u002fIP+4b1r5h7cs\u002fbN+w9g1rzz910UUXXXTRPzQzMzMzM9M\u002f8pQgTwny1D+x9g1r37DWP3BY+4a1b9g\u002fL7rooosu2j\u002fuG9a+Ye3bP619w9o3rN0\u002fbN+w9g1r3z+VIE8J8pTgP3XRRRdddOE\u002fVII8JchT4j80MzMzMzPjPxPkKUGeEuQ\u002f8pQgTwny5D\u002fSRRdddNHlP7H2DWvfsOY\u002fkacEeUqQ5z9wWPuGtW\u002foP1AJ8pQgT+k\u002fL7rooosu6j8Pa9+w9g3rP+4b1r5h7es\u002fzczMzMzM7D+tfcPaN6ztP4wuuuiii+4\u002fbN+w9g1r7z8myFOCPCXwP5UgTwnylPA\u002fBXlKkKcE8T910UUXXXTxP+QpQZ4S5PE\u002fVII8JchT8j\u002fE2jesfcPyPzQzMzMzM\u002fM\u002fo4suuuii8z8T5ClBnhL0P4M8JchTgvQ\u002f8pQgTwny9D9i7RvWvmH1P9JFF1100fU\u002fQp4S5ClB9j+x9g1r37D2PyFPCfKUIPc\u002fkacEeUqQ9z8BAAAAAAD4P3BY+4a1b\u002fg\u002f4LD2DWvf+D9QCfKUIE\u002f5P79h7RvWvvk\u002fL7rooosu+j+fEuQpQZ76Pw9r37D2Dfs\u002ffsPaN6x9+z\u002fuG9a+Ye37P1500UUXXfw\u002fzczMzMzM\u002fD89JchTgjz9P619w9o3rP0\u002fHda+Ye0b\u002fj+MLrrooov+P\u002fyGtW9Y+\u002f4\u002fbN+w9g1r\u002fz\u002fbN6x9w9r\u002fPybIU